# %% [markdown]
# ## Flow Segmentation

# %% [markdown]
# <p>
#   <a target="_blank" href="https://colab.research.google.com/github/AliRKhojasteh/Flow_segmentation/blob/main/Notebooks/Flow_segmentation.ipynb">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" height="30"/>
#   </a>
#
#   <a target="_blank" href="https://github.com/AliRKhojasteh/Flow_segmentation/Notebooks/Flow_segmentation">
#     <img src="https://img.shields.io/badge/-View%20on%20GitHub-blue?logo=github" alt="View on GitHub" height="30"/>
#   </a>
#
#   <a target="_blank" href="https://github.com/AliRKhojasteh/Flow_segmentation/Docs/tutorials.md">
#     <img src="https://img.shields.io/badge/-View%20Documentation-blue?logo=read-the-docs" alt="View Documentation" height="30"/>
#   </a>
# </p>

# %% [markdown]
# ## 1_ Read dependencies and install them

# %%
import os
import sys
import subprocess

repos = {
    "segment-anything": "https://github.com/facebookresearch/segment-anything.git",
    "GroundingDINO": "https://github.com/IDEA-Research/GroundingDINO.git",
    "supervision": "https://github.com/roboflow/supervision.git"
}

# If running in Google Colab, add the Flow_segmentation repository
try:
    import google.colab
    repos["Flow_segmentation"] = "https://github.com/AliRKhojasteh/Flow_segmentation.git"
except ImportError:
    pass

current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
scripts_dir = os.path.join(parent_dir, 'Scripts', 'libs')

sys.path.append(os.path.dirname(scripts_dir))

os.makedirs(scripts_dir, exist_ok=True)

for repo_name, repo_url in repos.items():
    repo_path = os.path.join(scripts_dir, repo_name)

    if os.path.isdir(repo_path):
        print(f"Pulling the latest version of {repo_name}...")
        subprocess.run(['git', 'pull'], cwd=repo_path, check=True)
    else:
        print(f"Cloning the repository {repo_name}...")
        subprocess.run(['git', 'clone', repo_url, repo_path], check=True)

    sys.path.append(repo_path)

    # Install the dependencies
    requirements_path = os.path.join(repo_path, 'requirements.txt')
    if os.path.isfile(requirements_path):
        print(f"Installing dependencies for {repo_name}...")
        subprocess.run(['pip', 'install', '-r', requirements_path], check=True)


try:
    import google.colab
    parent_dir = os.path.join(scripts_dir, "Flow_segmentation")
except ImportError:
    parent_dir = os.path.dirname(os.getcwd())

scripts_dir = os.path.join(parent_dir, "Scripts")
sys.path.append(scripts_dir)
# Out:
# Pulling the latest version of segment-anything...
# Already up to date.
# Pulling the latest version of GroundingDINO...
# Already up to date.
# Installing dependencies for GroundingDINO...
# Requirement already satisfied: torch in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from -r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (2.9.0)
# Requirement already satisfied: torchvision in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from -r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 2)) (0.24.0)
# Requirement already satisfied: transformers in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from -r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 3)) (4.57.1)
# Requirement already satisfied: addict in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from -r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 4)) (2.4.0)
# Requirement already satisfied: yapf in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from -r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 5)) (0.43.0)
# Requirement already satisfied: timm in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from -r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 6)) (1.0.20)
# Requirement already satisfied: numpy in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from -r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 7)) (2.2.6)
# Requirement already satisfied: opencv-python in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from -r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 8)) (4.12.0.88)
# Requirement already satisfied: supervision>=0.22.0 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from -r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 9)) (0.26.1)
# Requirement already satisfied: pycocotools in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from -r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 10)) (2.0.10)
# Requirement already satisfied: filelock in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (3.5)
# Requirement already satisfied: jinja2 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from torchvision->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 2)) (12.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from transformers->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 3)) (0.35.3)
# Requirement already satisfied: packaging>=20.0 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from transformers->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 3)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from transformers->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from transformers->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 3)) (2025.9.18)
# Requirement already satisfied: requests in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from transformers->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from transformers->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 3)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from transformers->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 3)) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from transformers->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 3)) (1.1.10)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from yapf->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 5)) (4.5.0)
# Requirement already satisfied: scipy>=1.10.0 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from supervision>=0.22.0->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 9)) (1.16.2)
# Requirement already satisfied: matplotlib>=3.6.0 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from supervision>=0.22.0->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 9)) (3.10.7)
# Requirement already satisfied: defusedxml>=0.7.1 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from supervision>=0.22.0->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 9)) (0.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from matplotlib>=3.6.0->supervision>=0.22.0->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from matplotlib>=3.6.0->supervision>=0.22.0->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from matplotlib>=3.6.0->supervision>=0.22.0->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 9)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from matplotlib>=3.6.0->supervision>=0.22.0->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 9)) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from matplotlib>=3.6.0->supervision>=0.22.0->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 9)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from matplotlib>=3.6.0->supervision>=0.22.0->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision>=0.22.0->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 9)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from requests->transformers->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 3)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from requests->transformers->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 3)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from requests->transformers->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from requests->transformers->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 3)) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from sympy>=1.13.3->torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/leo/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages (from jinja2->torch->-r /home/leo/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/requirements.txt (line 1)) (3.0.3)
# Pulling the latest version of supervision...
# Already up to date.

# %% [markdown]
# ## 2_ Loading the Input Image: Recommendations for Optimal Model Performance
#
# 1. **Format and Channels:** Ensure the image is in PNG format and utilizes three channels (RGB).
# 2. **Invert colors:** Consider inverting the image colors
# 2. **Colors:** Try different color maps.
# 3. **Image Pre-processing:** Additional pre-processing steps such as sharpening might be beneficial.
#
# All examples available in the 'demo' directory are permitted for demonstration purposes only. For additional usage permissions, please contact the corresponding authors listed in the references.
#
#
# For instructions on how to read and mask **DAVIS .im7** images, please refer to the [Mask_im7_files.ipynb](https://github.com/AliRKhojasteh/Flow_segmentation/blob/main/Notebooks/Mask_im7_files.ipynb).

# %%
import os
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

###### Change the text prompt here ######
text_prompt = 'Fingers and a hand'
print("Text input:", text_prompt)
#########################################

image_path = os.path.join(parent_dir, "Demo", "Fingers.png")
image_pil = Image.open(image_path).convert("RGB")

plt.figure(figsize=(5, 5))
plt.imshow(image_pil)
plt.show()

image_pil = ImageOps.invert(image_pil)
# Out:
# Text input: Fingers and a hand

# %% [markdown]
# <font color='red'>**Only for**</font> manually uploading your file in Colab. Otherwise, skip this cell!
#
# Does not work on the <font color='red'>**Safari browser!**</font>

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image, ImageOps

###### Change the text prompt here ######
text_prompt = 'Cylinder'
print("Text input:", text_prompt)
#########################################

try:
    # Try to import google.colab,
    # Step 1: Upload an image with the browse button
    # Step 2: Upload the image and show imshow

    from google.colab import files
    uploaded = files.upload()
    image_path = []
    for filename in uploaded.keys():

        # Save the file with its original filename
        uploaded_filename = list(uploaded.keys())[0]
        with open(uploaded_filename, 'wb') as f:
            f.write(uploaded[uploaded_filename])

        img = mpimg.imread(uploaded_filename)
        plt.imshow(img)
        plt.axis('off')
        plt.show()

        # Add the path of the uploaded image to the list
        # image_path.append(os.path.join(os.getcwd(), uploaded_filename))
        # image_pil = Image.open(image_path[0]).convert("RGB")
        image_path = os.path.join(os.getcwd(), list(uploaded.keys())[0])
        image_pil = Image.open(image_path).convert("RGB")        

except ImportError:
    image_path = os.path.join(parent_dir, "Demo", "Fingers.png")
    image_pil = Image.open(image_path).convert("RGB")
    image_pil = ImageOps.invert(image_pil) # if necessary

# %% [markdown]
# ## 3_ Mask Computation
#
# 1. **Select the size of the pre-trained Vision Transformer (ViT) model:**
#
#     - **vit_b** = "base"  # Base-sized model
#     - **vit_l** = "large"  # Large-sized model
#     - **vit_h** = "huge"  # Huge-sized model
#
# 2. **Computation Device:** cpu or cuda
# 3. **Language Model = bert-base-uncased**

# %%
import torch
import numpy as np
from Flow_segmentation import Superimpose_image_with_masks, Predictor, Groundingdino_model, Segmentation_model

######################### vit model type ##########################
sam_type="vit_h" # "vit_b" or "vit_l"

######### Auxiliary box in case text prompt does not work #########
aux_box = torch.tensor([[0, 200, 10, 10]])  # Replace with your auxiliary box in pixels x y w h

######### Point where you want to mask '1' or unmask '0' #########
input_point = None #np.array([[0, 100], [100, 450]]) # coordinates in pixels
input_label = None #np.array([0, 1]) # 1 for mask, 0 for unmask
###################################################################

# device = 'cuda' if torch.cuda.is_available() else 'cpu'
device = 'cpu'
print(f"Device: {device}")

groundingdino_model = Groundingdino_model()
sam_model = Segmentation_model(sam_type, ckpt_path=None, device=device)

masks, boxes, phrases, logits = Predictor(image_pil, text_prompt, input_point, input_label, groundingdino_model, sam_model, aux_box, box_threshold=0.3, text_threshold=0.25)

image_pil = ImageOps.invert(image_pil) # if necessary

if len(masks) == 0:
    print(f"No objects of the '{text_prompt}' prompt detected in the image.")
else:
    # Convert masks to numpy arrays
    masks_np = [mask.squeeze().cpu().numpy() for mask in masks]

    Superimpose_image_with_masks(image_pil, masks_np)
# Out:
# Device: cuda
# final text_encoder_type: bert-base-uncased
# Check the latest .pth from: https://github.com/IDEA-Research/GroundingDINO/releases
# Downloading: "https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth" to /home/leo/.cache/torch/hub/checkpoints/sam_vit_h_4b8939.pth
# 100%|██████████████████████████████████████| 2.39G/2.39G [00:39<00:00, 64.8MB/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 22
#      19 groundingdino_model = Groundingdino_model()
#      20 sam_model = Segmentation_model(sam_type, ckpt_path=None, device=device)
# ---> 22 masks, boxes, phrases, logits = Predictor(image_pil, text_prompt, input_point, input_label, groundingdino_model, sam_model, aux_box, box_threshold=0.3, text_threshold=0.25)
#      24 image_pil = ImageOps.invert(image_pil) # if necessary
#      26 if len(masks) == 0:
#
# File ~/MIE498Test/Flow_segmentation/Scripts/Flow_segmentation.py:119, in Predictor(image_pil, text_prompt, input_point, input_label, groundingdino_model, sam_model, aux_box, box_threshold, text_threshold)
#     116 image_trans, _ = transform(image_pil, None)
#     118 # GroundingDINO prediction
# --> 119 boxes, logits, phrases = dino_predict(model=groundingdino_model,
#     120                                       image=image_trans,
#     121                                       caption=text_prompt,
#     122                                       box_threshold=box_threshold,
#     123                                       text_threshold=text_threshold,
#     124                                       device=sam_model.device)
#     125 W, H = image_pil.size
#     126 boxes = box_ops.box_cxcywh_to_xyxy(boxes) * torch.Tensor([W, H, W, H])
#
# File ~/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/groundingdino/util/inference.py:68, in predict(model, image, caption, box_threshold, text_threshold, device, remove_combined)
#      65 image = image.to(device)
#      67 with torch.no_grad():
# ---> 68     outputs = model(image[None], captions=[caption])
#      70 prediction_logits = outputs["pred_logits"].cpu().sigmoid()[0]  # prediction_logits.shape = (nq, 256)
#      71 prediction_boxes = outputs["pred_boxes"].cpu()[0]  # prediction_boxes.shape = (nq, 4)
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/groundingdino/models/GroundingDINO/groundingdino.py:327, in GroundingDINO.forward(self, samples, targets, **kw)
#     324         self.poss.append(pos_l)
#     326 input_query_bbox = input_query_label = attn_mask = dn_meta = None
# --> 327 hs, reference, hs_enc, ref_enc, init_box_proposal = self.transformer(
#     328     srcs, masks, input_query_bbox, self.poss, input_query_label, attn_mask, text_dict
#     329 )
#     331 # deformable-detr-like anchor update
#     332 outputs_coord_list = []
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/groundingdino/models/GroundingDINO/transformer.py:258, in Transformer.forward(self, srcs, masks, refpoint_embed, pos_embeds, tgt, attn_mask, text_dict)
#     253 enc_topk_proposals = enc_refpoint_embed = None
#     255 #########################################################
#     256 # Begin Encoder
#     257 #########################################################
# --> 258 memory, memory_text = self.encoder(
#     259     src_flatten,
#     260     pos=lvl_pos_embed_flatten,
#     261     level_start_index=level_start_index,
#     262     spatial_shapes=spatial_shapes,
#     263     valid_ratios=valid_ratios,
#     264     key_padding_mask=mask_flatten,
#     265     memory_text=text_dict["encoded_text"],
#     266     text_attention_mask=~text_dict["text_token_mask"],
#     267     # we ~ the mask . False means use the token; True means pad the token
#     268     position_ids=text_dict["position_ids"],
#     269     text_self_attention_masks=text_dict["text_self_attention_masks"],
#     270 )
#     271 #########################################################
#     272 # End Encoder
#     273 # - memory: bs, \sum{hw}, c
#    (...)    277 # - enc_intermediate_refpoints: None or (nenc+1, bs, nq, c) or (nenc, bs, nq, c)
#     278 #########################################################
#     279 text_dict["encoded_text"] = memory_text
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/groundingdino/models/GroundingDINO/transformer.py:576, in TransformerEncoder.forward(self, src, pos, spatial_shapes, level_start_index, valid_ratios, key_padding_mask, memory_text, text_attention_mask, pos_text, text_self_attention_masks, position_ids)
#     574 # main process
#     575 if self.use_transformer_ckpt:
# --> 576     output = checkpoint.checkpoint(
#     577         layer,
#     578         output,
#     579         pos,
#     580         reference_points,
#     581         spatial_shapes,
#     582         level_start_index,
#     583         key_padding_mask,
#     584     )
#     585 else:
#     586     output = layer(
#     587         src=output,
#     588         pos=pos,
#    (...)    592         key_padding_mask=key_padding_mask,
#     593     )
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/_compile.py:53, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      50     disable_fn = torch._dynamo.disable(fn, recursive, wrapping=False)
#      51     fn.__dynamo_disable = disable_fn  # type: ignore[attr-defined]
# ---> 53 return disable_fn(*args, **kwargs)
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:1044, in DisableContext.__call__.<locals>._fn(*args, **kwargs)
#    1042 _maybe_set_eval_frame(_callback_from_stance(self.callback))
#    1043 try:
# -> 1044     return fn(*args, **kwargs)
#    1045 finally:
#    1046     set_eval_frame(None)
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/utils/checkpoint.py:496, in checkpoint(function, use_reentrant, context_fn, determinism_check, debug, early_stop, *args, **kwargs)
#     491     if context_fn is not noop_context_fn or debug is not False:
#     492         raise ValueError(
#     493             "Passing `context_fn` or `debug` is only supported when "
#     494             "use_reentrant=False."
#     495         )
# --> 496     return CheckpointFunction.apply(function, preserve, *args)
#     497 else:
#     498     gen = _checkpoint_without_reentrant_generator(
#     499         function, preserve, context_fn, determinism_check, debug, early_stop, *args, **kwargs
#     500     )
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/autograd/function.py:581, in Function.apply(cls, *args, **kwargs)
#     578 if not torch._C._are_functorch_transforms_active():
#     579     # See NOTE: [functorch vjp and autograd interaction]
#     580     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 581     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     583 if not is_setup_ctx_defined:
#     584     raise RuntimeError(
#     585         "In order to use an autograd.Function with functorch transforms "
#     586         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     587         "staticmethod. For more details, please see "
#     588         "https://pytorch.org/docs/main/notes/extending.func.html"
#     589     )
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/utils/checkpoint.py:262, in CheckpointFunction.forward(ctx, run_function, preserve_rng_state, *args)
#     259 ctx.save_for_backward(*tensor_inputs)
#     261 with torch.no_grad():
# --> 262     outputs = run_function(*args)
#     263 return outputs
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/groundingdino/models/GroundingDINO/transformer.py:785, in DeformableTransformerEncoderLayer.forward(self, src, pos, reference_points, spatial_shapes, level_start_index, key_padding_mask)
#     780 def forward(
#     781     self, src, pos, reference_points, spatial_shapes, level_start_index, key_padding_mask=None
#     782 ):
#     783     # self attention
#     784     # import ipdb; ipdb.set_trace()
# --> 785     src2 = self.self_attn(
#     786         query=self.with_pos_embed(src, pos),
#     787         reference_points=reference_points,
#     788         value=src,
#     789         spatial_shapes=spatial_shapes,
#     790         level_start_index=level_start_index,
#     791         key_padding_mask=key_padding_mask,
#     792     )
#     793     src = src + self.dropout1(src2)
#     794     src = self.norm1(src)
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/groundingdino/models/GroundingDINO/ms_deform_attn.py:338, in MultiScaleDeformableAttention.forward(self, query, key, value, query_pos, key_padding_mask, reference_points, spatial_shapes, level_start_index, **kwargs)
#     335     sampling_locations = sampling_locations.float()
#     336     attention_weights = attention_weights.float()
# --> 338 output = MultiScaleDeformableAttnFunction.apply(
#     339     value,
#     340     spatial_shapes,
#     341     level_start_index,
#     342     sampling_locations,
#     343     attention_weights,
#     344     self.im2col_step,
#     345 )
#     347 if halffloat:
#     348     output = output.half()
#
# File ~/miniforge3/envs/MIE498UTD/lib/python3.12/site-packages/torch/autograd/function.py:581, in Function.apply(cls, *args, **kwargs)
#     578 if not torch._C._are_functorch_transforms_active():
#     579     # See NOTE: [functorch vjp and autograd interaction]
#     580     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 581     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     583 if not is_setup_ctx_defined:
#     584     raise RuntimeError(
#     585         "In order to use an autograd.Function with functorch transforms "
#     586         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     587         "staticmethod. For more details, please see "
#     588         "https://pytorch.org/docs/main/notes/extending.func.html"
#     589     )
#
# File ~/MIE498Test/Flow_segmentation/Scripts/libs/GroundingDINO/groundingdino/models/GroundingDINO/ms_deform_attn.py:53, in MultiScaleDeformableAttnFunction.forward(ctx, value, value_spatial_shapes, value_level_start_index, sampling_locations, attention_weights, im2col_step)
#      42 @staticmethod
#      43 def forward(
#      44     ctx,
#    (...)     50     im2col_step,
#      51 ):
#      52     ctx.im2col_step = im2col_step
# ---> 53     output = _C.ms_deform_attn_forward(
#      54         value,
#      55         value_spatial_shapes,
#      56         value_level_start_index,
#      57         sampling_locations,
#      58         attention_weights,
#      59         ctx.im2col_step,
#      60     )
#      61     ctx.save_for_backward(
#      62         value,
#      63         value_spatial_shapes,
#    (...)     66         attention_weights,
#      67     )
#      68     return output
#
# NameError: name '_C' is not defined

# %% [markdown]
# ## 4_ Save Masks
# - **npy**: Save in .npy, a binary format for storing NumPy arrays.
# - **mat**: Save in .mat, storing **MATLAB** arrays.
# - **png**: Save as .png,
# - **txt**: Save in .txt,

# %%
import os
from Save_masks import save_masks_to_file

# Get the directory and base name of the file
save_dir = os.path.dirname(image_path)
save_name = os.path.splitext(os.path.basename(image_path))[0]
format = 'mat' # 'npy', 'mat', 'png', or 'txt'

save_masks_to_file(masks, save_dir, save_name, format)
